# %% [markdown]
# # ECTMetrics

# %% [markdown]
# ## Simple usage example
# This basic example demonstrates how to generate an EEG signal and calculate ECT seizure quality indices utilizing the `ectmetrics` library.
# ___

# %% [markdown]
# If you haven't done so yet, begin by installing the `ectmetrics` library using PIP.

# %% [raw]
# pip install ectmetrics

# %% [markdown]
# Or alternatively by cloning it with Git.

# %% [raw]
# git clone https://github.com/maxkayser/ectmetrics
# cd ectmetrics
# pip install .

# %% [markdown]
# Import the `ectmetrics` library.

# %%
import ectmetrics
from ectmetrics.eeg import generate, plot

# %% [markdown]
# Now generate a synthetic EEG signal by calling the `generate()` function and specifying its parameters.

# %%
# Generate an EEG signal
eeg_data = generate(
    signal_duration = 34,      # Duration of the EEG signal in seconds
    seizure_duration = 25,     # Duration of the seizure in seconds
    sampling_frequency = 200,  # Sampling frequency of the signal in Hz
    eeg_name = 'ECT EEG'        # Name or identifier for the EEG
)

# %% [markdown]
# Let's visualize the EEG

# %%
# Visualize the signals
plot(eeg_data)

# %% [markdown]
# Now use the `metric()` function in order to calculate the seizure quality metrics

# %%
from ectmetrics.metrics import metric

# Calculate the ECT seizure quality metrics
metrics_results = metric(eeg_data)

metrics_results
# Out:
# [{'name': 'asei',
#   'description': 'Average Seizure Energy Index',
#   'options': None,
#   'value': 20323.68126392354,
#   'unit': 'μV²',
#   'timepoints': {'startpoint': 0, 'endpoint': 5000}},
#  {'name': 'sei',
#   'description': 'Seizure Energy Index',
#   'options': None,
#   'value': 508092.0315980885,
#   'unit': 'μV²·s',
#   'timepoints': {'startpoint': 0, 'endpoint': 5000}},
#  {'name': 'psi',
#   'description': 'Postictal Suppression Index',
#   'options': None,
#   'value': 82.89362359204792,
#   'unit': '%',
#   'timepoints': {'startpoint': 3848, 'endpoint': 6152}},
#  {'name': 'eia',
#   'description': 'Early Ictal Amplitude',
#   'options': None,
#   'value': 125.87476253825271,
#   'unit': 'μV',
#   'timepoints': {'startpoint': 0, 'endpoint': 2048}},
#  {'name': 'mia',
#   'description': 'Midictal Amplitude',
#   'options': None,
#   'value': 127.59303219798146,
#   'unit': 'μV',
#   'timepoints': {'startpoint': 1024, 'endpoint': 3072}},
#  {'name': 'msp',
#   'description': 'Maximum Sustained Power',
#   'options': None,
#   'value': 44294407896.88732,
#   'unit': 'μV²/Hz',
#   'timepoints': {'startpoint': 1024, 'endpoint': 3072}},
#  {'name': 'ttpp',
#   'description': 'Time to Peak Power',
#   'options': None,
#   'value': 10.24,
#   'unit': 's',
#   'timepoints': {'timepoint': 2048}},
#  {'name': 'coh',
#   'description': 'Maximum Sustained Coherence',
#   'options': None,
#   'value': 61.487582580726865,
#   'unit': '%',
#   'timepoints': {'startpoint': 2560, 'endpoint': 3584}},
#  {'name': 'ttpc',
#   'description': 'Time to Peak Coherence',
#   'options': None,
#   'value': 15.36,
#   'unit': 's',
#   'timepoints': {'timepoint': 3072}}]

# %% [markdown]
# For easier visualization of the results, represent the output as a DataFrame using the `pandas` library.

# %%
import pandas as pd

df_metrics = pd.DataFrame(metrics_results).set_index('name')
df_metrics
# Out:
#                        description options         value    unit  \
# name
# asei  Average Seizure Energy Index    None  2.032368e+04     μV²
# sei           Seizure Energy Index    None  5.080920e+05   μV²·s
# psi    Postictal Suppression Index    None  8.289362e+01       %
# eia          Early Ictal Amplitude    None  1.258748e+02      μV
# mia             Midictal Amplitude    None  1.275930e+02      μV
# msp        Maximum Sustained Power    None  4.429441e+10  μV²/Hz
# ttpp            Time to Peak Power    None  1.024000e+01       s
# coh    Maximum Sustained Coherence    None  6.148758e+01       %
# ttpc        Time to Peak Coherence    None  1.536000e+01       s
#
#                                   timepoints
# name
# asei     {'startpoint': 0, 'endpoint': 5000}
# sei      {'startpoint': 0, 'endpoint': 5000}
# psi   {'startpoint': 3848, 'endpoint': 6152}
# eia      {'startpoint': 0, 'endpoint': 2048}
# mia   {'startpoint': 1024, 'endpoint': 3072}
# msp   {'startpoint': 1024, 'endpoint': 3072}
# ttpp                     {'timepoint': 2048}
# coh   {'startpoint': 2560, 'endpoint': 3584}
# ttpc                     {'timepoint': 3072}

# %% [markdown]
# ___
# **Contact Information**
#
# For more details, please refer to the [contact file](../CONTACT.md).
#
# **Citing ECTMetrics**
#
# If you utilize the `ectmetrics` library in your research or projects, please refer to the [citations file](../CITATIONS.md) in this repository for proper citation guidance.
